# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## Project 5: Deploying Your LangGraph App as a Production API
#
#
# #### After building and testing your travel agent locally, the final step is to turn it into a reliable, scalable web service. In this project, we'll use LangServe to turn your LangGraph application into a REST API, integrate LangSmith for comprehensive observability, and package everything into a Docker container for consistent, repeatable deployment.

# %%
# !pip install langgraph-cli

# %% [markdown]
# creating a `langgraph.json` configuration file in project's root directory. The file tells CLI how to build and run the app.

# %%
{
    'dependencies': ["."],
    'graph': {
        "travel_agent": "./pro_20_4_travel_assit.ipynb",
    },
    'env': '.evn'
}
# Out:
# {'dependencies': ['.'],
#  'graph': {'travel_agent': './pro_20_4_travel_assit.ipynb'},
#  'env': '.evn'}

# %% [markdown]
# The configuration json file in place will helps to build docker image for the LangGraph app with single command

# %%
langgraph build -t travel-agent:latest
# Out:
#   Cell In[6], line 1
#     langgraph build -t travel-agent:latest
#               ^
# SyntaxError: invalid syntax
