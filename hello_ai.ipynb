# %%
# openai key def
az_aoai_key = "place_your_key"
az_model="palce_your_model_name"
az_endpoint="place_your_endpoint"
api_ver="place_api_version"

# %%
# import statement

from azure.core.credentials import AzureKeyCredential
from langchain_openai import AzureChatOpenAI
from langchain_core.messages import HumanMessage

# %%
# building chat client
chat_llm = AzureChatOpenAI(
    api_key=az_aoai_key,
    azure_endpoint=az_endpoint,
    model=az_model,
    api_version=api_ver
)

# %%
messages = HumanMessage(content="Tell me a joke about hardware engineer")

# %%
response = chat_llm.invoke([messages])

# %%
print(response.content)
# Out:
# Sure! Here's a joke for you:
#
# Why did the hardware engineer break up with their partner?
#
# Because they couldn't handle the resistance!
