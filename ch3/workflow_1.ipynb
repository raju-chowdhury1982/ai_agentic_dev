# %%
from typing import TypedDict
from typing import Literal
from langgraph.graph import StateGraph, START, END

# %%
# 1. def state schema
class RouterState(TypedDict):
    user_query: str
    priority_level: str

# %%
# 2. def the Nodes - python function that perform action and update state
def high_priority_node(state: RouterState) -> RouterState:
    print("Routing to high priority agent...")
    return {"priority_level": "High"}
